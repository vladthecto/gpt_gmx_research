# %%
import os
import pandas as pd
from datetime import datetime

# Path where CSV files are stored on Google Drive or locally
path = "./market_data"
path2 = "./tweets"

# %% [markdown]
# #1 Binance history

# %%
# Names of the attributes for the dataframe
column_names = ["OpenTime", "OpenPrice", "HighPrice", "LowPrice", "ClosePrice", "Volume", "CloseTime", "QuoteVolume", "TradesN", "TakerVol", "TakerQVol", "Ignore"]  # Replace with your actual column names

# Store all the dataframes from each CSV file
dfs = []

# Loop through all files in the directory
for filename in os.listdir(path):
    if filename.endswith(".csv"):
        df = pd.read_csv(os.path.join(path, filename), names=column_names)

        # Assuming "date" is the name of the column that has unix timestamps
        df['OpenTime'] = pd.to_datetime(df['OpenTime'], unit='ms')  # Convert Unix timestamp to datetime
        df['CloseTime'] = pd.to_datetime(df['CloseTime'], unit='ms')  # Convert Unix timestamp to datetime

        dfs.append(df)

# Concatenate all dataframes
result = pd.concat(dfs)

# Sort the dataframe by date
result = result.sort_values(by=['OpenTime'])

# Reset the index of the final dataframe
result = result.reset_index(drop=True)

# %%
print(result)
# Out:
#                   OpenTime  OpenPrice  HighPrice  LowPrice  ClosePrice  \
# 0      2023-04-01 00:00:00    1821.52    1822.38   1821.51     1822.30
# 1      2023-04-01 00:01:00    1822.29    1822.30   1821.66     1821.67
# 2      2023-04-01 00:02:00    1821.67    1822.16   1821.50     1821.86
# 3      2023-04-01 00:03:00    1821.87    1821.87   1821.32     1821.32
# 4      2023-04-01 00:04:00    1821.32    1821.33   1821.32     1821.33
# ...                    ...        ...        ...       ...         ...
# 115195 2023-06-19 23:55:00    1735.13    1735.36   1735.12     1735.36
# 115196 2023-06-19 23:56:00    1735.35    1736.29   1735.35     1736.28
# 115197 2023-06-19 23:57:00    1736.28    1736.76   1735.93     1736.76
# 115198 2023-06-19 23:58:00    1736.75    1737.99   1736.73     1737.70
# 115199 2023-06-19 23:59:00    1737.70    1737.73   1737.04     1737.11
#
#           Volume               CloseTime    QuoteVolume  TradesN  TakerVol  \
# 0       174.2847 2023-04-01 00:00:59.999  317547.289220      407  138.3378
# 1       135.6274 2023-04-01 00:01:59.999  247128.202315      381   81.2480
# 2       245.4449 2023-04-01 00:02:59.999  447176.414980      481  143.3722
# 3        77.5005 2023-04-01 00:03:59.999  141172.885903      354   39.2423
# 4        83.1847 2023-04-01 00:04:59.999  151506.426250      335   46.8446
# ...          ...                     ...            ...      ...       ...
# 115195   42.8766 2023-06-19 23:55:59.999   74402.706415      141   38.2281
# 115196  134.2732 2023-06-19 23:56:59.999  233106.315512      185  121.7527
# 115197   57.4815 2023-06-19 23:57:59.999   99797.619945      132   32.8234
# 115198  124.5393 2023-06-19 23:58:59.999  216369.374176      255   91.9340
# 115199  246.9829 2023-06-19 23:59:59.999  429130.994258      225  206.0969
#
#             TakerQVol  Ignore
# 0       252044.440338       0
# 1       148043.609682       0
# 2       261197.548148       0
# 3        71482.719381       0
# 4        85319.475318       0
# ...               ...     ...
# 115195   66336.640593       0
# 115196  211370.277319       0
# 115197   56983.781239       0
# 115198  159714.923798       0
# 115199  358089.645670       0
#
# [115200 rows x 12 columns]

# %% [markdown]
# #2 Filtering rise / fall events

# %%
def find_rapid_price_changes(df, change_pct, interval_minutes):
    # Create an empty list to store the result rows
    result_rows = []

    # Iterate over the rows of the DataFrame
    for i in range(len(df) - interval_minutes):
        # Select the current row and the rows in the next interval_minutes
        window_df = df.iloc[i : i + interval_minutes]

        # Calculate the maximum percentage change in the interval
        max_change_fall = (window_df['HighPrice'].max() - window_df['LowPrice'].min()) / window_df['HighPrice'].max()
        max_change_rise = (window_df['HighPrice'].max() - window_df['LowPrice'].min()) / window_df['LowPrice'].min()

        # If the maximum percentage change is greater than change_pct, add the current row to the result
        if max_change_fall > change_pct / 100 or max_change_rise > change_pct / 100:
            result_row = df.iloc[i].copy()
            if window_df.iloc[0]['OpenPrice'] < window_df.iloc[-1]['ClosePrice']:
                result_row['Direction'] = 'rise'
            else:
                result_row['Direction'] = 'fall'
            result_rows.append(result_row)

    # Concatenate all result rows into a DataFrame
    result = pd.concat(result_rows, axis=1).transpose()

    return result

# %%
# More than X% in Y minutes (1,5% and 5 minutes in the code below)
priceDif = 1.5
timeFrame = 5
rapid_changes_df = find_rapid_price_changes(result, priceDif, timeFrame)

# %%
print(rapid_changes_df)
# Out:
#                   OpenTime OpenPrice HighPrice LowPrice ClosePrice  \
# 4983   2023-04-04 11:03:00   1831.96   1834.03   1830.0    1833.28
# 4984   2023-04-04 11:04:00   1833.29   1836.34  1833.28    1835.72
# 4985   2023-04-04 11:05:00   1835.72   1837.51  1835.54    1836.62
# 4986   2023-04-04 11:06:00   1836.62    1838.0  1836.32    1837.75
# 4987   2023-04-04 11:07:00   1837.75   1871.11  1837.43    1866.82
# ...                    ...       ...       ...      ...        ...
# 111217 2023-06-17 05:37:00   1725.68   1726.57  1725.68    1726.57
# 111218 2023-06-17 05:38:00   1726.57   1726.57  1725.69    1725.98
# 111219 2023-06-17 05:39:00   1725.98   1727.13  1725.97     1726.9
# 111220 2023-06-17 05:40:00    1726.9   1728.84  1726.89    1728.39
# 111221 2023-06-17 05:41:00   1728.38    1770.0  1728.38    1757.15
#
#             Volume               CloseTime      QuoteVolume TradesN  \
# 4983     1925.8777 2023-04-04 11:03:59.999   3526731.165971    1560
# 4984     1832.7732 2023-04-04 11:04:59.999   3364330.831436    2623
# 4985     1467.2397 2023-04-04 11:05:59.999    2694729.53495    2222
# 4986      988.2258 2023-04-04 11:06:59.999    1815563.96114    1766
# 4987    16952.2054 2023-04-04 11:07:59.999  31377519.614125   25744
# ...            ...                     ...              ...     ...
# 111217     99.7444 2023-06-17 05:37:59.999    172161.363477     200
# 111218      227.36 2023-06-17 05:38:59.999    392457.597089     274
# 111219    138.6827 2023-06-17 05:39:59.999    239424.924656     280
# 111220    523.7054 2023-06-17 05:40:59.999    904977.982742     935
# 111221  16704.9958 2023-06-17 05:41:59.999  29269479.734648   25182
#
#           TakerVol        TakerQVol Ignore Direction
# 4983      940.2493   1721827.199851      0      rise
# 4984      843.8592   1548880.134262      0      rise
# 4985      860.7835   1580832.916265      0      rise
# 4986      661.7337   1215713.803286      0      rise
# 4987    11666.2303  21590969.216328      0      rise
# ...            ...              ...    ...       ...
# 111217     91.5087    157945.185219      0      rise
# 111218      80.826    139485.569506      0      rise
# 111219     121.172    209194.364228      0      rise
# 111220    416.1299    719044.213918      0      rise
# 111221  10622.5966  18611402.304507      0      rise
#
# [172 rows x 13 columns]

# %%
fall_df = rapid_changes_df[rapid_changes_df['Direction'] == 'fall']
print(fall_df.count())
# Out:
# OpenTime       106
# OpenPrice      106
# HighPrice      106
# LowPrice       106
# ClosePrice     106
# Volume         106
# CloseTime      106
# QuoteVolume    106
# TradesN        106
# TakerVol       106
# TakerQVol      106
# Ignore         106
# Direction      106
# dtype: int64

# %%
rise_df = rapid_changes_df[rapid_changes_df['Direction'] == 'rise']
print(rise_df.count())
# Out:
# OpenTime       66
# OpenPrice      66
# HighPrice      66
# LowPrice       66
# ClosePrice     66
# Volume         66
# CloseTime      66
# QuoteVolume    66
# TradesN        66
# TakerVol       66
# TakerQVol      66
# Ignore         66
# Direction      66
# dtype: int64

# %% [markdown]
# Finding "Eventful" days and hours to plan the implementation of the model being developed.

# %%
# Extract hour and day of week from 'OpenTime' 
rapid_changes_df['hour'] = rapid_changes_df['OpenTime'].dt.hour
rapid_changes_df['day_of_week'] = rapid_changes_df['OpenTime'].dt.dayofweek

# Group by 'day_of_week' and 'hour' and calculate the count of events
weekday_hourly_events = rapid_changes_df.groupby(['day_of_week', 'hour']).size()

# Sort by day_of_week and then by the count of events within each hour
weekday_hourly_events_sorted = weekday_hourly_events.sort_index().groupby(level=0, group_keys=False).apply(lambda x: x.sort_values(ascending=False))

# Check the result
print(weekday_hourly_events_sorted)
# Out:
# day_of_week  hour
# 0            1        9
#              15       4
#              16       4
#              17       4
# 1            11       5
# 2            19      19
#              20      15
#              8       10
#              12      10
#              17       9
#              0        5
#              23       4
#              2        1
# 3            0        8
#              1        5
#              6        3
#              16       3
#              8        1
#              15       1
# 4            0        8
#              12       5
#              19       5
#              18       4
#              16       3
#              15       2
# 5            5        5
#              14       5
#              4        3
#              7        3
#              8        2
#              18       2
# 6            22       3
#              21       2
# dtype: int64

# %% [markdown]
# We need a "no change" class as well, cuz "no change" is the most popular event to happen, and our classificator needs to be familiar with it.

# %%
from datetime import timedelta

#result_df - overall dataframe
#change_df - rapid changes dataframe
# N - desirable number of events to choose
# M - hours to exclude around the rapid change
def generate_no_change_events(result_df, change_df, N, M):
   
    # Create a list to store the dates to exclude
    exclude_dates = []

    # For each event in change_df, add all dates in a range of M hours around the event to exclude_dates
    for date in change_df['OpenTime']:
        start_date = date - timedelta(hours=M/2)
        end_date = date + timedelta(hours=M/2)
        date_range = pd.date_range(start=start_date, end=end_date, freq='min')
        exclude_dates.extend(date_range)

    # Exclude all rows from result_df that are in exclude_dates
    no_change_df = result_df.loc[~result_df['OpenTime'].isin(exclude_dates)]

    # Randomly select N rows from no_change_df
    no_change_df = no_change_df.sample(N)

    return no_change_df

# %%
# Using the function to generate "no change events"
no_change_df = generate_no_change_events(result, rapid_changes_df, 200, 20) 

print(no_change_df)
# Out:
#                   OpenTime  OpenPrice  HighPrice  LowPrice  ClosePrice  \
# 47917  2023-05-04 06:37:00    1898.31    1899.10   1898.31     1899.09
# 2037   2023-04-02 09:57:00    1821.67    1821.68   1821.63     1821.64
# 98991  2023-06-08 17:51:00    1844.01    1844.33   1844.00     1844.32
# 105100 2023-06-12 23:40:00    1742.74    1742.99   1742.73     1742.99
# 90854  2023-06-03 02:14:00    1901.69    1901.70   1901.69     1901.69
# ...                    ...        ...        ...       ...         ...
# 45867  2023-05-02 20:27:00    1871.34    1871.69   1869.98     1869.99
# 108796 2023-06-15 13:16:00    1642.55    1643.05   1642.55     1642.95
# 80175  2023-05-26 16:15:00    1829.41    1830.00   1829.41     1829.99
# 57936  2023-05-11 05:36:00    1827.96    1827.96   1827.50     1827.79
# 114474 2023-06-19 11:54:00    1725.95    1726.04   1725.74     1725.75
#
#           Volume               CloseTime    QuoteVolume  TradesN  TakerVol  \
# 47917   160.3148 2023-05-04 06:37:59.999  304397.103191      311  143.6834
# 2037     66.2047 2023-04-02 09:57:59.999  120601.270742      190   60.3992
# 98991    73.7214 2023-06-08 17:51:59.999  135958.245592      145   71.4637
# 105100   15.7312 2023-06-12 23:40:59.999   27419.164011       82    9.0219
# 90854    31.9241 2023-06-03 02:14:59.999   60709.860453       88   11.8724
# ...          ...                     ...            ...      ...       ...
# 45867   298.4789 2023-05-02 20:27:59.999  558444.529934      456   71.7822
# 108796  130.5391 2023-06-15 13:16:59.999  214444.651282      229   90.0245
# 80175   120.1677 2023-05-26 16:15:59.999  219859.812805      217   45.7855
# 57936   109.1570 2023-05-11 05:36:59.999  199514.911162      187   42.5582
# 114474   69.7937 2023-06-19 11:54:59.999  120464.419495      143    9.9555
#
#             TakerQVol  Ignore
# 47917   272821.584581       0
# 2037    110025.726793       0
# 98991   131794.866125       0
# 105100   15725.029947       0
# 90854    22577.743080       0
# ...               ...     ...
# 45867   134297.145580       0
# 108796  147883.268790       0
# 80175    83771.838010       0
# 57936    77785.048367       0
# 114474   17182.786842       0
#
# [200 rows x 12 columns]

# %% [markdown]
# #3 Twitter preparation part

# %%
# Names of the attributes for the dataframe
column_names = ["ID", "Link", "datetime", "Account", "AccountName", "text", "Media", "Engage1", "Engage2", "Engage3", "Engage4"]  # Replace with your actual column names

# Store all the dataframes from each CSV file
dfs = []

# Loop through all files in the directory
for filename in os.listdir(path2):
    if filename.endswith(".csv"):
        df = pd.read_csv(os.path.join(path2, filename), names=column_names)

        # Assuming "date" is the name of the column that has unix timestamps
        df['datetime'] = pd.to_datetime(df['datetime'], format='%b %d, %Y · %I:%M %p %Z')

        dfs.append(df)

# Concatenate all dataframes
tweets_df = pd.concat(dfs)

# Sort the dataframe by date
tweets_df = tweets_df.sort_values(by=['datetime'])

# Reset the index of the final dataframe
tweets_df = tweets_df.reset_index(drop=True)

# %%
print(tweets_df)
# Out:
#                         ID                                               Link  \
# 0      1641954253114580994  https://twitter.com/financialjuice/status/1641...
# 1      1641954189826826246  https://twitter.com/financialjuice/status/1641...
# 2      1641954241953628161  https://twitter.com/financialjuice/status/1641...
# 3      1642129051803348992  https://twitter.com/financialjuice/status/1642...
# 4      1642129207781195776  https://twitter.com/financialjuice/status/1642...
# ...                    ...                                                ...
# 10718  1670869603843440643  https://twitter.com/financialjuice/status/1670...
# 10719  1670875129067237384  https://twitter.com/financialjuice/status/1670...
# 10720  1670893526664507397  https://twitter.com/financialjuice/status/1670...
# 10721  1670904077268426754  https://twitter.com/financialjuice/status/1670...
# 10722  1670929350613426177  https://twitter.com/financialjuice/status/1670...
#
#                        datetime          Account           AccountName  \
# 0     2023-04-01 00:02:00+00:00  @financialjuice  Breaking Market News
# 1     2023-04-01 00:02:00+00:00  @financialjuice  Breaking Market News
# 2     2023-04-01 00:02:00+00:00  @financialjuice  Breaking Market News
# 3     2023-04-01 11:37:00+00:00  @financialjuice  Breaking Market News
# 4     2023-04-01 11:38:00+00:00  @financialjuice  Breaking Market News
# ...                         ...              ...                   ...
# 10718 2023-06-19 19:02:00+00:00  @financialjuice  Breaking Market News
# 10719 2023-06-19 19:24:00+00:00  @financialjuice  Breaking Market News
# 10720 2023-06-19 20:37:00+00:00  @financialjuice  Breaking Market News
# 10721 2023-06-19 21:19:00+00:00  @financialjuice  Breaking Market News
# 10722 2023-06-19 22:59:00+00:00  @financialjuice  Breaking Market News
#
#                                                     text Media  Engage1  \
# 0      S. KOREAN TRADE BALANCE PRELIM ACTUAL -4.62B (...   NaN        1
# 1      S. KOREAN EXPORTS PRELIM ACTUAL -13.6% (FORECA...   NaN        1
# 2      S. KOREAN IMPORTS PRELIM ACTUAL -6.4% (FORECAS...   NaN        1
# 3      ECB'S DE GUINDOS: THE EUROZONE BANKING SECTOR ...   NaN        9
# 4      ECB'S DE GUINDOS: HEADLINE INFLATION IS LIKELY...   NaN        1
# ...                                                  ...   ...      ...
# 10718  ECB'S DE GUINDOS: INFLATION IS TO EASE BUT COR...   NaN        5
# 10719  TUESDAY'S FX OPTION EXPIRIES\n\nHTTPS://WWW.FI...   NaN        5
# 10720  BIDEN: US-CHINA RELATIONS ARE ON THE RIGHT TRAIL.   NaN       18
# 10721  MORNING JUICE - ASIA SESSION PREP financialjui...   NaN        2
# 10722  NEW ZEALAND TREASURY: DOMESTIC DEMAND IS BEING...   NaN        2
#
#        Engage2  Engage3  Engage4
# 0            6        0       20
# 1            2        0       15
# 2            1        0       11
# 3           11        3       58
# 4            4        0       27
# ...        ...      ...      ...
# 10718        6        0       24
# 10719        0        0        7
# 10720       10        3       82
# 10721        3        0       10
# 10722        7        1       37
#
# [10723 rows x 11 columns]

# %% [markdown]
# #4 Dataset preparation

# %%
def generate_combined_df(rise_fall_df, no_change_df, tweets_df):
    # Convert the 'datetime' column of tweets_df to datetime if it isn't already
    tweets_df['datetime'] = pd.to_datetime(tweets_df['datetime'])
    # Convert all tweet texts to strings
    tweets_df['text'] = tweets_df['text'].astype(str)

    # Concatenate rise_fall_df and no_change_df
    combined_df = pd.concat([rise_fall_df, no_change_df])

    # Sort combined_df by 'OpenTime'
    combined_df = combined_df.sort_values('OpenTime')

    # Create a 'tweets' column in combined_df
    combined_df['tweets'] = ''

    # Convert 'OpenTime' to UTC to match the timezone of 'datetime' in tweets_df
    combined_df['OpenTime'] = combined_df['OpenTime'].dt.tz_localize('UTC')

    # For each row in combined_df, find all tweets in tweets_df that occurred within the 8 hours before the event
    for i, row in combined_df.iterrows():
        try:
            start_time = row['OpenTime'] - timedelta(hours=8)
            relevant_tweets = tweets_df[(tweets_df['datetime'] >= start_time) & (tweets_df['datetime'] < row['OpenTime'])]

            # Sort the relevant tweets by 'datetime'
            relevant_tweets = relevant_tweets.sort_values('datetime')

            # Join the tweet texts together with ' // ' as the separator and add them to the 'tweets' column
            #combined_df.loc[i, 'tweets'] = ' // '.join(relevant_tweets['text'])
            combined_df.loc[i, 'tweets'] = '\n'.join(relevant_tweets['text'])
        except TypeError as e:
            print(f'Error at index {i}: {e}')
            print('Value causing error:', relevant_tweets['text'])

    return combined_df

# %%
# Use the function
combined_df = generate_combined_df(rapid_changes_df, no_change_df, tweets_df)

print(combined_df)
# Out:
#                         OpenTime OpenPrice HighPrice LowPrice ClosePrice  \
# 733    2023-04-01 12:13:00+00:00   1824.71   1824.87  1824.71    1824.79
# 1101   2023-04-01 18:21:00+00:00   1814.32   1814.43  1813.78    1814.43
# 1952   2023-04-02 08:32:00+00:00   1818.74   1818.91  1818.74     1818.9
# 2037   2023-04-02 09:57:00+00:00   1821.67   1821.68  1821.63    1821.64
# 2429   2023-04-02 16:29:00+00:00   1792.79    1794.1  1792.79    1792.99
# ...                          ...       ...       ...      ...        ...
# 112779 2023-06-18 07:39:00+00:00   1731.02   1731.03  1730.97    1730.98
# 113085 2023-06-18 12:45:00+00:00   1735.71   1736.27  1734.83    1736.23
# 113710 2023-06-18 23:10:00+00:00   1723.84   1724.34  1723.22    1724.33
# 114400 2023-06-19 10:40:00+00:00   1725.08   1725.08  1724.69    1725.07
# 114474 2023-06-19 11:54:00+00:00   1725.95   1726.04  1725.74    1725.75
#
#           Volume               CloseTime    QuoteVolume TradesN  TakerVol  \
# 733     209.8126 2023-04-01 12:13:59.999  382864.474937     318  128.7462
# 1101    196.6477 2023-04-01 18:21:59.999  356714.735043     319   50.3513
# 1952    120.7518 2023-04-02 08:32:59.999  219618.902875     252    91.915
# 2037     66.2047 2023-04-02 09:57:59.999  120601.270742     190   60.3992
# 2429    264.4631 2023-04-02 16:29:59.999  474269.513855     642  120.3334
# ...          ...                     ...            ...     ...       ...
# 112779   22.0003 2023-06-18 07:39:59.999   38082.270614     177    2.4138
# 113085  276.8724 2023-06-18 12:45:59.999  480513.324716     539  155.5568
# 113710  197.2032 2023-06-18 23:10:59.999  339908.969495     196  158.8211
# 114400  218.5093 2023-06-19 10:40:59.999   376922.37625     287  117.4692
# 114474   69.7937 2023-06-19 11:54:59.999  120464.419495     143    9.9555
#
#             TakerQVol Ignore Direction  \
# 733     234932.007283      0       NaN
# 1101     91332.881275      0       NaN
# 1952    167171.412591      0       NaN
# 2037    110025.726793      0       NaN
# 2429    215781.034381      0       NaN
# ...               ...    ...       ...
# 112779    4178.256974      0       NaN
# 113085  269967.828142      0       NaN
# 113710  273751.750876      0       NaN
# 114400  202627.078361      0       NaN
# 114474   17182.786842      0       NaN
#
#                                                    tweets
# 733     ECB'S DE GUINDOS: THE EUROZONE BANKING SECTOR ...
# 1101    ECB'S DE GUINDOS: THE EUROZONE BANKING SECTOR ...
# 1952
# 2037
# 2429
# ...                                                   ...
# 112779
# 113085  UK'S CHANCELLOR HUNT RULES OUT DIRECT SUPPORT ...
# 113710  SENIOR US STATE DEPT. OFFICIALS: US SECRETARY ...
# 114400  CHINA'S TOP ENVOY WANG YI IN MEETING WITH BLIN...
# 114474  CHINA'S TOP ENVOY WANG YI IN MEETING WITH BLIN...
#
# [372 rows x 14 columns]

# %%
#let's check random rows to be sure the format's OK
import random

# Set X to the number of random rows you want to view
X = 3

# Generate X random indices
random_indices = random.sample(range(len(combined_df)), X)

# Print the 'tweets' field of the random rows
for i in random_indices:
    print(f'Row {i} \n{combined_df.iloc[i]["OpenTime"]} tweets:\n{combined_df.iloc[i]["tweets"]}\n')
# Out:
# Row 33
# 2023-04-09 02:25:00+00:00 tweets:
# CHINA LAUNCHED MILITARY DRILLS AFTER TAIWAN PRESIDENT TSAI ING-WEN’S US TRIP - FT. ft.com/content/e25807de-16ed…
#
# Row 177
# 2023-05-05 12:29:00+00:00 tweets:
# SINGAPORE RETAIL SALES YOY ACTUAL 4.5% (FORECAST -1.1%, PREVIOUS 12.7%) $MACRO
# SINGAPORE RETAIL SALES MOM ACTUAL 2.2% (FORECAST -, PREVIOUS 3.9%) $MACRO
# MORNING JUICE - EUROPEAN SESSION PREP financialjuice.com/News/7392…
# SWISS UNEMPLOYMENT RATE UNADJUSTED ACTUAL 2.0% (FORECAST -, PREVIOUS 2.0%) $MACRO
# SWISS UNEMPLOYMENT RATE ADJUSTED ACTUAL 1.9% (FORECAST 1.9%, PREVIOUS 1.9%) $MACRO
# GERMAN INDUSTRIAL ORDERS MOM ACTUAL -10.7% (FORECAST -2.3%, PREVIOUS 4.8%) $MACRO
# ECB'S VILLEROY: THE CHANGE IN THE RATE INCREASE RYTHM IS AN IMPORTANT SIGNAL.
# ECB'S VILLEROY: I FAVOR SMALLER ECB RATE INCREASES.
# ECB'S VILLEROY: THERE WILL LIKELY BE SEVERAL MORE HIKES, BUT WE HAVE DONE THE ESSENTIAL.
# ECB'S VILLEROY: THE ECONOMIC SITUATION IS RESILIENT IN FRANCE AND IN THE EURO ZONE.
# ECB'S VILLEROY: WE WILL BRING INFLATION BACK TO 2% BY 2025, MAYBE EVEN BY THE END OF 2024.
# ECB'S VILLEROY: I'M NOT WORRIED ABOUT EUROPEAN BANKS.
# SWISS CPI YOY ACTUAL 2.6% (FORECAST 2.8%, PREVIOUS 2.9%) $MACRO
# SWISS CPI MOM ACTUAL 0% (FORECAST 0.2%, PREVIOUS 0.2%) $MACRO
# ECB'S VASLE: FURTHER STEPS WILL DEPEND ON ECONOMIC DATA.
# FRENCH NON-FARM PAYROLLS QOQ ACTUAL 0.2% (FORECAST 0.1%, PREVIOUS 0.2%) $MACRO
# FRENCH INDUSTRIAL PRODUCTION MOM ACTUAL -1.1% (FORECAST -0.4%, PREVIOUS 1.2%) $MACRO
# FRENCH INDUSTRIAL PRODUCTION MARCH 2023 FULL REPORT insee.fr/en/statistiques/761…
# UK PM SUNAK ON LOCAL ELECTION RESULTS: IT'S STILL EARLY, BUT I'LL CARRY ON DELIVERING ON PEOPLE'S PRIORITIES.
# CURRENCY STRENGTH CHART: STRONGEST - AUD, WEAKEST - CHF.
# FRENCH S&P CONSTRUCTION PMI ACTUAL 46.0 (FORECAST -, PREVIOUS 45.3) $MACRO
# ITALIAN S&P CONSTRUCTION PMI ACTUAL 49.0 (FORECAST -, PREVIOUS 47.4) $MACRO
# EUROZONE S&P CONSTRUCTION PMI ACTUAL 45.2 (FORECAST -, PREVIOUS 45.0) $MACRO
# GERMAN S&P CONSTRUCTION PMI ACTUAL 42 (FORECAST -, PREVIOUS 42.9) $MACRO
# EUROZONE CONSTRUCTION PMI APRIL 2023 FULL REPORT pmi.spglobal.com/Public/Home…
# ITALIAN CONSTRUCTION PMI APRIL 2023 FULL REPORT pmi.spglobal.com/Public/Home…
# FRENCH CONSTRUCTION PMI APRIL 2023 FULL REPORT pmi.spglobal.com/Public/Home…
# GERMAN CONSTRUCTION PMI APRIL 2023 FULL REPORT pmi.spglobal.com/Public/Home…
# EU COMMISSION VP SEFCOVIC: THE GAS PRICE IS STILL NOT ACCEPTABLE FOR US.
# ITALIAN RETAIL SALES MOM ACTUAL 0.00% (FORECAST -0.45%, PREVIOUS -0.10%) $MACRO
# ITALIAN RETAIL SALES NSA YOY ACTUAL 5.80% (FORECAST -, PREVIOUS 5.80%) $MACRO
# EURO ZONE COMPANIES SAY GROWTH IN SELLING PRICES IS MODERATING - ECB SURVEY OF FORECASTERS.
# THE ECB 2023 GDP GROWTH AT 0.6% AND 2024 GROWTH AT 1.2% - ECB SURVEY OF FORECASTERS.
# EURO ZONE COMPANIES SEE WAGE GROWTH AT AROUND 5% IN 2023 VS 3% IN 2022, UNCHANGED FROM THE PREVIOUS SURVEY - ECB SURVEY OF FORECASTERS.
# THE ECB SEES 2025 INFLATION PROJECTED AT 2.2% VS 2.1% SEEN EARLIER; LONGER-TERM UNCHANGED AT 2.1% - ECB SURVEY OF FORECASTERS.
# THE ECB SEES 2023 INFLATION AT 5.6% VS 5.9% PREVIOUSLY; 2024 AT 2.6% VS 2.7% - ECB SURVEY OF FORECASTERS.
# ECB'S SIMKUS: MORE IS NEEDED TO CURB INFLATION THAT REMAINS TOO HIGH.
# ECB'S SIMKUS: THURSDAY'S RATE INCREASE WASN'T THE LAST.
# UBS NOW EXPECTS THE ECB TO DELIVER A 25BPS INTEREST RATE HIKE IN JULY, TAKING THE TERMINAL RATE TO 3.75%.
# UK S&P CONSTRUCTION PMI ACTUAL 51.1 (FORECAST 51, PREVIOUS 50.7) $MACRO
# GERMAN ECONOMY MINISTRY - THE GOAL IS FOR COMPANIES TO REMAIN INTERNATIONALLY COMPETITIVE.
# GERMAN ECONOMY MINISTRY - WE PROPOSE AN INDUSTRIAL ELECTRICITY PRICE OF 6 CENTS PER KILOWATT PER HOUR UNTIL 2030.
# EUROZONE RETAIL SALES YOY ACTUAL -3.8% (FORECAST -3.3%, PREVIOUS -3.0%) $MACRO
# EUROZONE RETAIL SALES MOM ACTUAL -1.2% (FORECAST -0.2%, PREVIOUS -0.8%) $MACRO
# EUROZONE RETAIL SALES MARCH 2023 FULL REPORT ec.europa.eu/eurostat/docume…
# ECB'S MULLER: NO ONE KNOWS HOW HIGH RATES MUST BE RAISED.
# ECB'S MULLER: THE LATEST INTEREST-RATE INCREASE WON'T BE THE LAST.
# ECB'S MULLER: THERE IS NO SIGN YET OF A CLEAR SLOWDOWN IN CORE INFLATION.
# SNB'S CHAIRMAN JORDAN: WE CANNOT EXCLUDE FURTHER TIGHTENING OF MONETARY POLICY.
# SNB'S CHAIRMAN JORDAN: INFLATION IS STILL AN ISSUE IN SWITZERLAND.
# $59.5 BLN INFLOWS TO CASH FUNDS, $11 BLN TO BONDS, $200 MLN TO GOLD, IN THE WEEK TO MAY 3RD - BOFA CITING EPFR DATA.
# $6.6 BLN OUTFLOWS FROM EQUITIES LARGEST WEEKLY OUTFLOW IN NINE WEEKS, $1 BLN OUTFLOW FROM US GROWTH FUNDS, THE LARGEST IN 10 WEEKS - BOFA CITING EPFR DATA.
# BOFA BULL & BEAR INDICATOR RISES TO 3.2, AT NEUTRAL, UP FROM 2.9 LAST WEEK ON INFLOWS TO EM STOCKS.
# SNB'S CHAIRMAN JORDAN: SWISS BANKS COULD SEE SOME VALUATION LOSSES ON PROPERTY.
# SNB'S CHAIRMAN JORDAN: SNB TRIES EVERYTHING TO AVOID NEGATIVE EQUITY.
# SNB'S CHAIRMAN JORDAN: WE CAN'T RULE OUT THAT IT WILL BE NECESSARY AGAIN TO FURTHER TIGHTEN MONETARY POLICY.
# RUSSIA PIPELINE DATA PROVIDES SCANT EVIDENCE OF OIL OUTPUT CUTS.
# TRADE NFP AND CANADIAN EMPLOYMENT CHANGE WITH US AT 8 AM ET LIVE! invidious.fdn.fr/yoZVGCWQ5L4
# S&P: EU CRYPTO REGULATION COULD SHAPE GLOBAL STANDARDS.
# SECURED OVERNIGHT FINANCING RATE 5.06% MAY 4 VS 4.81% MAY 3.
# US NONFARM PAYROLLS PREP financialjuice.com/News/7393…
# MORNING JUICE - US SESSION financialjuice.com/News/7393…
#
# Row 215
# 2023-05-10 17:18:00+00:00 tweets:
# CHINA SEEKS TO RESUME AND BROADEN TAIWAN COMMUNICATIONS - XINHUA
# GERMAN 30 YR 1.8% BUND AUCTION
#
# BID/COVER 2.0
#
# AVERAGE YIELD 2.53%
#
# SELLS €1.232 BLN
#
# SELLS 30-YR BUND AT 84.75 AND ABOVE
# DEUTSCHE BANK: WE SEES POTENTIAL DOVISH RISKS AT THE BOE MEETING THIS THURSDAY.
# DEUTSCHE BANK: WE NO LONGER THINKS THE POUND IS ATTRACTIVE IN THE SHORT TERM.
# DEUTSCHE BANK: WE ARE TAKING PROFIT ON THE POUND AGAINST THE US DOLLAR AFTER STERLING'S RECENT RALLY.
# KREMLIN DECLINES COMMENT ON BLACK SEA GRAIN DEAL TALKS.
# KREMLIN: WE NEED TO WAIT AND SEE WHAT THE NEGOTIATIONS PROCESS PRODUCES.
# EU COMMISSION VP SEFCOVIC: 77 COMPANIES HAVE ENROLLED TO THE FIRST TENDER FOR FIRST JOINT EU GAS BUYING.
# EU COMMISSION VP SEFCOVIC: THE TOTAL DEMAND FOR VOLUME IN TENDER IS 11.6 BCM OF GAS.
# EU ENVOYS APPROVE NEW CRYPTO LEGAL FRAMEWORK MICA.
# MILITARY OBJECT FOUND IN POLISH FOREST IN APRIL WAS RUSSIAN CH-55 MISSILE - POLISH MEDIA CITE UNNAMED SOURCES.
# US DOJ IS LOOKING AT SHORT SELLING ACTIVITY IN REGIONAL BANK SHARES, ACCORDING TO A SOURCE.
# DOJ IS LOOKING FOR POSSIBILITY OF SECURITIES MARKET MANIPULATION - SOURCE.
# ECB'S MULLER: RATES STILL NEED TO BE RAISED BUT NOT AS QUICKLY.
# ECB'S MULLER: SLOWER RATE HIKES ALLOWS THE ECB TO ASSESS ACTION SO FAR.
# US MBA MORTGAGE APPLICATIONS ACTUAL 6.3% (FORECAST -, PREVIOUS -1.2%) $MACRO
# US MBA 30-YR MORTGAGE RATE ACTUAL 6.48% (FORECAST -, PREVIOUS 6.50%) $MACRO
# TRADE US CPI WITH US LIVE AT 8 AM ET! invidious.fdn.fr/YxpsOjFL4_0
# TURKEY HAS DEFERRED $600 MLN GAS PAYMENT TO RUSSIA UNTIL 2024, ACCORDING TO SOURCES.
# TURKEY MAY DEFER TOTAL OF $3-4 BLN IN ENERGY PAYMENTS TO RUSSIA DEPENDING ON GLOBAL PRICES - SOURCES
# MORE TURKISH NATURAL GAS BILLS TO RUSSIA MAY BE POSTPONED IN THE COMING MONTHS AS PART OF DEAL - SOURCES.
# TURKEY GAS PAYMENT DEFERRAL IS FIRST SUCH TRANSACTION IT HAS POSTPONED UNDER RECENT DEAL - SOURCES.
# CHINA HAS ASKED BANKS TO LOWER INTEREST RATE CEILINGS ON SOME RETAIL AND CORPORATE DEPOSITS, EFFECTIVE MAY 15 - SOURCES
# MORNING JUICE - US SESSION financialjuice.com/News/7401…
# US CPI PREP  financialjuice.com/News/7401…
# SECURED OVERNIGHT FINANCING RATE 5.06% MAY 9, UNCHANGED.
# HAPPY CPI DAY 🥳
# catch CPi live with us >>> financialjuice.com
# CANADIAN BUILDING PERMITS MOM ACTUAL 11.3% (FORECAST -2.2%, PREVIOUS 8.6% ,REVISION 5.5%) $MACRO
# US CPI MOM ACTUAL 0.4% (FORECAST 0.4%, PREVIOUS 0.1%) $MACRO
# ⚠️ BREAKING: US CPI YOY ACTUAL 4.9% (FORECAST 5%, PREVIOUS 5.0%) $MACRO
# US CORE CPI YOY ACTUAL 5.5% (FORECAST 5.5%, PREVIOUS 5.6%) $MACRO
# US CORE CPI MOM ACTUAL 0.4% (FORECAST 0.4%, PREVIOUS 0.4%) $MACRO
# US SHORT-TERM INTEREST-RATE FUTURES RISE AFTER CPI REPORT, AS TRADERS ADD TO BETS ON FED PAUSE IN JUNE.
# US CPI APRIL 2023 FULL REPORT. bls.gov/news.release/cpi.nr0…
# FED SWAPS DOWNGRADE THE ODDS OF A 25 BPS JUNE RATE-HIKE.
# CANADIAN BUILDING PERMITS MARCH 2023 FULL REPORT. www150.statcan.gc.ca/n1/dail…
# US GOVERNMENT 1-YR CDS RISE TO 172 BPS FROM 163 BPS ON TUESDAY - S&P GLOBAL MARKET INTELLIGENCE DATA.
# US TREASURY SECRETARY YELLEN TO HOST NEWS CONFERENCE ON MAY 11TH IN JAPAN.
# IRAQ: WE ARE STILL WAITING ON TURKEY TO RESTART CEYHAN OIL EXPORTS.
# EFFECTIVE FED FUNDS RATE 5.08% MAY 9TH VS 5.08% MAY 8TH
# BP CEO: THE RISK OF DEEP RECESSION IS LOW AND REMOTE.
# UAE'S ROYAL GROUP SHORTS US STOCKS ON GLOBAL RECESSION FEARS.
# HOUSE REP. SPEAKER MCCARTHY SAID THE POLLING IS WITH REPUBLICANS AND SAID THEY HAVE TO KEEP UP THE PRESSURE ON POTUS - PUNCHBOWL NEWS
# HOUSE REP. SPEAKER MCCARTHY ADDED THAT SENATE REPUBLICANS ARE WITH HOUSE GOP BECAUSE THEY PASSED A BILL ALREADY - PUNCHBOWL NEWS.
# NASDAQ HITS HIGHEST LEVEL SINCE AUGUST 2022, LAST UP 1.0% AFTER THE CPI DATA.
# TRADE BOE BANK RATE WITH US AT 6:30 AM ET THURSDAY LIVE! invidious.fdn.fr/O20k-Yp-nWs
# EUROPE'S STOXX 600 DOWN 0.5%, ERASING GAINS THAT FOLLOWED US CPI DATA.
# WATCH LIVE - HEARING ENTITLED: THE FUTURE OF DIGITAL ASSETS invidious.fdn.fr/i43Ckphd9vo
# BANK OF PORTUGAL: SUSTAINED REDUCTION OF INFLATION WILL CONTINUE TO BE ECB'S PRIORITY.
# BANK OF PORTUGAL: INFLATION IS STILL HIGH AND PROJECTIONS POINT TO GRADUAL DECLINE.
# BANK OF PORTUGAL: MAIN RISKS ARE THE ECB'S MONETARY POLICY, FRICTIONS IN GLOBAL FINANCIAL MARKETS AND GEOPOLITICS.
# NISSAN CHIEF WARNS ON THREAT POSED BY CHINESE RIVALS’ RAPID PACE OF PRODUCTION - FT.
# NISSAN CHIEF WARNS ON THREAT POSED BY CHINESE RIVALS’ RAPID PACE OF PRODUCTION - FT. ft.com/content/c387fa14-bf63…
# UK GOVERNMENT: WE ARE MODIFYING THE RETAINED EU LAW BILL TO BE CLEAR WHICH LAWS WE PLAN TO RESCIND AT THE END OF THIS YEAR.
# SOME ECB OFFICIALS BEGIN TO THINK SEPTEMBER RATE HIKE MAY BE REQUIRED.
# JPMORGAN CEO DIMON: THERE IS A HIGHER CHANCE OF MISTAKE ON THE DEBT LIMIT - PUNCHBOWL.
# JPMORGAN CEO DIMON: I HOPE THE US GETS RID OF DEBT LIMIT ONE DAY - PUNCHBOWL.
# CRYPTO FEAR AND GREED INDEX: 52/100 = NEUTRAL.
# WHITE HOUSE: CPI REPORT IS SHOWING PROGRESS, HOWEVER A DEFAULT IS BIGGEST THREAT.
# JPMORGAN CEO DIMON: THE US NEEDS A TOUGH AND THOUGHTFUL APPROACH TO CHINA - PUNCHBOWL
# US SENATE MAJORITY LEADER SCHUMER: STAFF-LEVEL DISCUSSIONS ON DEBT LIMIT BEGIN TODAY.
# EIA CRUDE CUSHING INVENTORIES  ACTUAL 0.397M (FORECAST -, PREVIOUS 0.541M) $MACRO
# EIA GASOLINE INVENTORIES ACTUAL -3.167M (FORECAST -1.5M, PREVIOUS 1.743M) $MACRO
# EIA DISTILLATE INVENTORIES ACTUAL -4.17M (FORECAST -1M, PREVIOUS -1.191M) $MACRO
# ⚠️ BREAKING: EIA CRUDE OIL INVENTORIES ACTUAL 2.951M (FORECAST -2.5M, PREVIOUS -1.280M) $MACRO
# EIA: INVENTORIES OF CRUDE IN THE SPR OFF 2.9 MLN BBLS TO 362.01 MLN.
# EIA INVENTORIES REPORT ir.eia.gov/wpsr/overview.pdf
# EIA: US CRUDE STOCKS IN SPR FELL LAST WEEK TO THE LOWEST SINCE OCTOBER 1983.
# US SENATE REPUBLICAN LEADER MCCONNELL: WHITE HOUSE UNILATERAL ACTION ON THE DEBT CEILING WITHOUT CONGRESS IS NOT AN OPTION.
# UBS SCRUTINIZES CREDIT SUISSE’S ASIA LENDING IN RISK ASSESSMENT. THEY'RE CONCERNED AT QUALITY OF SOME CREDIT SUISSE ASIA LOANS.
# UBS CONSIDERS OPTIONS INVOLVING CREDIT BOOK SALES AND UNWINDING LOANS.
# TETHER: WE'RE REDUCING RELIANCE ON PURE BANK DEPOSITS AS A SOURCE OF LIQUIDITY, LEVERAGING REPO MARKET - STATEMENT ON WEBSITE.
# ECB'S CENTENO: MONETARY POLICY, AS MEASURED BY SETTING KEY RATES, IS AT ITS PEAK FOR THIS CYCLE..
# ECB'S CENTENO: INTEREST RATES ADJUSTMENT IS STILL UNDERWAY.
# ECB'S CENTENO: INTEREST RATES HISTORICALLY ARE NOT HIGH, BUT THEY ARE RISING QUICKLY.
# ECB'S CENTENO: ECB POLICY WILL REMAIN TIGHT FOR SOME TIME AFTER RATE PEAK.
# ECB'S CENTENO: RATES SHOULD BEGIN TO COME DOWN AT SOME POINT DURING 2024.
# ECB'S CENTENO: WE MUST BE APPROACHING THE TERMINAL RATE. IF THIS IS DONE IN JUNE OR JULY, THERE IS A VERY CRUCIAL CONDITION THAT IS INFLATION.
# ECB'S CENTENO: AT SOME POINT NEXT YEAR, RATES MAY BE CUT.
# JAPANESE INVESTORS WILL SOON FILE REQUEST FOR ARBITRATION REGARDING CREDIT SUISSE'S ADDITIONAL TIER 1 BONDS - NIKKEI.
# JAPANESE INVESTORS WILL SOON FILE REQUEST FOR ARBITRATION REGARDING CREDIT SUISSE'S ADDITIONAL TIER 1 BONDS - NIKKEI. asia.nikkei.com/Business/Fin….
# ITALY'S PM MELONI: NO DECISION HAS YET BEEN MADE ON LEAVING BRI DEAL WITH CHINA, HOWEVER DEBATE IS OPEN.
# WHITE HOUSE: DEBT LIMIT TALKS WERE PRODUCTIVE AND EVERYONE UNDERSTOOD THE RISK OF DEFAULT.
# WHITE HOUSE: STAFF WILL MEET DAILY ON DEBT UNTIL THE LEADERS MEET AGAIN FRIDAY.
# SENATE BANKING TO CONSIDER BERNSTEIN NOMINATION ON MAY 11TH.
# ITALY'S PM MELONI: I DIDN'T BACK THE CHINA PACT WHEN IT WAS SIGNED - ANSA.
# SNB'S CHAIRMAN JORDAN: INFLATION IS HIGHER THAN WE WANT IT TO BE.
# FIRST CITIZENS SHARED LOSS AGREEMENT WITH FDIC IN CONNECTION WITH PURCHASE OF SVB COVERS ESTIMATED $60 BLN OF COMMERCIAL LOANS.
# FIRST CITIZENS: FDIC WILL REIMBURSE COMPANY FOR 0% OF LOSSES OF UP TO $5 BLN OVER COVERED ASSETS, 50% OF LOSSES IN EXCESS OF $5 BLN OVER COVERED ASSETS.
# SNB'S CHAIRMAN JORDAN: THE SNB'S SWIFT ACTION HELPED TAME INFLATION.
# SNB'S CHAIRMAN JORDAN: NOMINAL SWISS FRANC APPRECIATION IS MOSTLY DUE TO INFLATION ABROAD.
# SNB'S CHAIRMAN JORDAN: MONETARY POLICY AT THE MOMENT IS STILL NOT RESTRICTIVE ENOUGH.
# SNB'S CHAIRMAN JORDAN: WE DON'T ANTICIPATE A WAGE-PRICE-SPIRAL, BUT THERE ARE RISKS.
# SNB'S CHAIRMAN JORDAN: WE'RE PREPARED TO USE FX SALES AS POLICY TOOL IF NECESSARY.
# FED BIDS FOR 10-YR NOTES TOTAL $9.5 BLN.
# TREASURY WI 10 YR YIELD 3.439% BEFORE $35 BILLION AUCTION.
# TURKEY'S FOREIGN MINISTER: UKRAINE BLACK SEA GRAIN DEAL COULD BE EXTENDED FOR AT LEAST TWO MORE MONTHS.
# US 10-YEAR NOTE AUCTION ACTUAL 3.448% (FORECAST -, PREVIOUS 3.455%) $MACRO
# US 10-YEAR NOTE BID-TO-COVER ACTUAL 2.45 (FORECAST -, PREVIOUS 2.36) $MACRO
# US 10 YR NOTE AUCTION
#
# BID-TO-COVER 2.45
#
# HIGH YIELD 3.448%
#
# AWARDS 70.70% OF BIDS AT HIGH
#
# SELLS $35 BLN
# WHITE HOUSE ADVISOR SPERLING: I AM SEEING A PRODUCTIVE PROCESS ON DEBT LIMIT TALKS.
# 104 COUNTERPARTIES TAKE $2.233 TLN AT FED REVERSE REPO OPERATION.

# %%
# Let's filter out empty rows (happens sometime)
# Create a boolean mask for rows where 'tweets' is empty
empty_tweets_mask = combined_df['tweets'] == ''

# Filter combined_df using the mask
empty_tweets_df = combined_df[empty_tweets_mask]

# Print the rows with empty 'tweets'
print(empty_tweets_df)

# Print the number of rows with empty 'tweets'
print(f'Number of rows with empty "tweets": {len(empty_tweets_df)}')
# Out:
#                         OpenTime OpenPrice HighPrice LowPrice ClosePrice  \
# 1952   2023-04-02 08:32:00+00:00   1818.74   1818.91  1818.74     1818.9
# 2037   2023-04-02 09:57:00+00:00   1821.67   1821.68  1821.63    1821.64
# 2429   2023-04-02 16:29:00+00:00   1792.79    1794.1  1792.79    1792.99
# 10644  2023-04-08 09:24:00+00:00   1869.56   1869.57  1869.55    1869.56
# 11885  2023-04-09 06:05:00+00:00   1828.84   1830.32  1828.47    1829.83
# 12069  2023-04-09 09:09:00+00:00   1838.01   1838.01  1837.63    1837.64
# 12074  2023-04-09 09:14:00+00:00   1838.19    1838.2  1838.19     1838.2
# 12239  2023-04-09 11:59:00+00:00   1839.44   1839.44  1839.21    1839.22
# 21149  2023-04-15 16:29:00+00:00   2103.01   2103.85   2103.0    2103.26
# 22233  2023-04-16 10:33:00+00:00   2086.24   2086.54  2086.24    2086.53
# 22368  2023-04-16 12:48:00+00:00   2088.35   2088.36  2088.34    2088.34
# 22438  2023-04-16 13:58:00+00:00   2083.65   2087.44  2083.64    2085.29
# 22569  2023-04-16 16:09:00+00:00   2092.68   2092.68  2092.67    2092.68
# 30836  2023-04-22 09:56:00+00:00   1851.35   1851.71  1851.35    1851.53
# 31500  2023-04-22 21:00:00+00:00   1869.34   1869.34  1868.18    1868.51
# 31966  2023-04-23 04:46:00+00:00   1863.23   1863.23  1863.13    1863.13
# 32073  2023-04-23 06:33:00+00:00   1870.59   1870.62  1870.09     1870.1
# 32461  2023-04-23 13:01:00+00:00   1872.14   1873.53  1872.13    1873.53
# 32544  2023-04-23 14:24:00+00:00   1874.27   1874.27  1872.87    1872.87
# 40669  2023-04-29 05:49:00+00:00   1900.49   1900.68  1900.48    1900.67
# 41084  2023-04-29 12:44:00+00:00   1897.65   1897.65  1897.16    1897.24
# 42296  2023-04-30 08:56:00+00:00   1902.99    1903.0  1902.99     1903.0
# 50877  2023-05-06 07:57:00+00:00   1959.02   1959.25  1958.35    1958.36
# 50878  2023-05-06 07:58:00+00:00   1958.36   1958.59  1958.35    1958.58
# 50879  2023-05-06 07:59:00+00:00   1958.59   1959.44  1958.58    1958.92
# 50880  2023-05-06 08:00:00+00:00   1958.91   1958.92  1956.48    1957.33
# 50881  2023-05-06 08:01:00+00:00   1957.32   1957.33   1923.0    1938.16
# 51242  2023-05-06 14:02:00+00:00   1899.27   1899.27  1898.45    1898.79
# 51243  2023-05-06 14:03:00+00:00    1898.8   1898.92  1897.24    1897.59
# 51244  2023-05-06 14:04:00+00:00   1897.59    1897.8   1892.0     1897.8
# 51245  2023-05-06 14:05:00+00:00    1897.8    1898.0  1893.51    1894.99
# 51246  2023-05-06 14:06:00+00:00    1895.0   1895.33   1860.0     1872.1
# 51930  2023-05-07 01:30:00+00:00    1915.1   1917.88   1915.1    1917.13
# 62480  2023-05-14 09:20:00+00:00   1803.29    1803.3  1802.48    1802.48
# 71008  2023-05-20 07:28:00+00:00   1809.85   1810.61  1809.84     1810.6
# 71206  2023-05-20 10:46:00+00:00   1813.63   1813.64  1813.63    1813.64
# 72640  2023-05-21 10:40:00+00:00   1813.08   1813.09  1812.43    1812.44
# 81271  2023-05-27 10:31:00+00:00   1826.54   1826.54  1826.53    1826.54
# 81372  2023-05-27 12:12:00+00:00   1826.88   1826.88  1826.35    1826.54
# 91181  2023-06-03 07:41:00+00:00   1905.39   1905.66  1905.39    1905.66
# 91211  2023-06-03 08:11:00+00:00   1903.54   1903.55  1903.54    1903.54
# 92723  2023-06-04 09:23:00+00:00   1904.56   1905.88  1904.55    1904.63
# 92774  2023-06-04 10:14:00+00:00   1904.84   1904.85  1904.25    1904.26
# 101062 2023-06-10 04:22:00+00:00   1818.42    1823.6  1815.15    1815.91
# 101063 2023-06-10 04:23:00+00:00   1815.91   1817.27  1808.16    1813.36
# 101064 2023-06-10 04:24:00+00:00   1813.36   1816.32  1801.38    1802.56
# 102644 2023-06-11 06:44:00+00:00   1756.88   1757.13  1756.75    1756.76
# 102796 2023-06-11 09:16:00+00:00   1747.88   1747.88  1747.87    1747.87
# 111217 2023-06-17 05:37:00+00:00   1725.68   1726.57  1725.68    1726.57
# 111218 2023-06-17 05:38:00+00:00   1726.57   1726.57  1725.69    1725.98
# 111219 2023-06-17 05:39:00+00:00   1725.98   1727.13  1725.97     1726.9
# 111220 2023-06-17 05:40:00+00:00    1726.9   1728.84  1726.89    1728.39
# 111221 2023-06-17 05:41:00+00:00   1728.38    1770.0  1728.38    1757.15
# 112175 2023-06-17 21:35:00+00:00   1728.17   1728.18   1727.5     1727.5
# 112356 2023-06-18 00:36:00+00:00   1725.75   1726.49  1725.74    1726.49
# 112469 2023-06-18 02:29:00+00:00   1725.99    1726.0  1725.43    1725.44
# 112779 2023-06-18 07:39:00+00:00   1731.02   1731.03  1730.97    1730.98
#
#             Volume               CloseTime      QuoteVolume TradesN  \
# 1952      120.7518 2023-04-02 08:32:59.999    219618.902875     252
# 2037       66.2047 2023-04-02 09:57:59.999    120601.270742     190
# 2429      264.4631 2023-04-02 16:29:59.999    474269.513855     642
# 10644      23.2418 2023-04-08 09:24:59.999      43452.02945     700
# 11885    1354.9599 2023-04-09 06:05:59.999   2478847.406597    1680
# 12069     125.3633 2023-04-09 09:09:59.999    230398.309217    1026
# 12074      53.2312 2023-04-09 09:14:59.999     97849.335568     999
# 12239     120.4888 2023-04-09 11:59:59.999    221621.763558     827
# 21149     188.3363 2023-04-15 16:29:59.999    396172.819144     370
# 22233      68.1239 2023-04-16 10:33:59.999    142125.884364     218
# 22368     193.6128 2023-04-16 12:48:59.999    404331.393387     167
# 22438     382.8703 2023-04-16 13:58:59.999     798507.77221     906
# 22569      27.8326 2023-04-16 16:09:59.999     58244.555542      99
# 30836     156.8173 2023-04-22 09:56:59.999    290359.527603     203
# 31500     223.5338 2023-04-22 21:00:59.999    417694.732719     452
# 31966      87.1572 2023-04-23 04:46:59.999    162387.647075     107
# 32073     121.1314 2023-04-23 06:33:59.999    226574.431396     170
# 32461      61.4213 2023-04-23 13:01:59.999     115019.03393     201
# 32544     100.4689 2023-04-23 14:24:59.999    188250.410297     259
# 40669       49.047 2023-04-29 05:49:59.999     93215.716708     107
# 41084      42.5995 2023-04-29 12:44:59.999     80824.985379     160
# 42296      19.4667 2023-04-30 08:56:59.999      37045.08138     103
# 50877     115.2158 2023-05-06 07:57:59.999    225705.622871     328
# 50878      93.6992 2023-05-06 07:58:59.999    183500.012122     339
# 50879     310.0161 2023-05-06 07:59:59.999    607253.119236     457
# 50880      671.693 2023-05-06 08:00:59.999   1314723.770952     808
# 50881    13730.489 2023-05-06 08:01:59.999  26624677.269449   15785
# 51242     516.2968 2023-05-06 14:02:59.999    980348.829968     546
# 51243     374.9463 2023-05-06 14:03:59.999    711657.599625     630
# 51244    4132.5651 2023-05-06 14:04:59.999    7831211.79905    2632
# 51245      528.542 2023-05-06 14:05:59.999   1001850.893072     849
# 51246   18176.6509 2023-05-06 14:06:59.999  34108142.920327   21260
# 51930     675.1555 2023-05-07 01:30:59.999   1294338.558897     837
# 62480     112.6621 2023-05-14 09:20:59.999    203110.813414     222
# 71008      81.0012 2023-05-20 07:28:59.999    146613.372017     182
# 71206      18.0854 2023-05-20 10:46:59.999     32800.299269     110
# 72640     163.8771 2023-05-21 10:40:59.999    297059.789596     423
# 81271      15.4003 2023-05-27 10:31:59.999      28129.16919     112
# 81372     103.6426 2023-05-27 12:12:59.999    189313.419969     175
# 91181      53.7634 2023-06-03 07:41:59.999    102449.172324     300
# 91211      17.3787 2023-06-03 08:11:59.999     33081.134412     171
# 92723     286.2171 2023-06-04 09:23:59.999     545327.53016     607
# 92774      61.6997 2023-06-04 10:14:59.999    117509.250627     183
# 101062   4890.7131 2023-06-10 04:22:59.999   8894580.980018    4791
# 101063   8883.0952 2023-06-10 04:23:59.999  16100386.868026    7982
# 101064   5006.8953 2023-06-10 04:24:59.999   9062754.207551    5201
# 102644     94.4049 2023-06-11 06:44:59.999    165872.667227     332
# 102796      76.314 2023-06-11 09:16:59.999    133387.090485     594
# 111217     99.7444 2023-06-17 05:37:59.999    172161.363477     200
# 111218      227.36 2023-06-17 05:38:59.999    392457.597089     274
# 111219    138.6827 2023-06-17 05:39:59.999    239424.924656     280
# 111220    523.7054 2023-06-17 05:40:59.999    904977.982742     935
# 111221  16704.9958 2023-06-17 05:41:59.999  29269479.734648   25182
# 112175    119.1838 2023-06-17 21:35:59.999    205938.359858     175
# 112356     63.8982 2023-06-18 00:36:59.999    110290.685394     175
# 112469     33.2767 2023-06-18 02:29:59.999     57427.042209     120
# 112779     22.0003 2023-06-18 07:39:59.999     38082.270614     177
#
#           TakerVol        TakerQVol Ignore Direction tweets
# 1952        91.915    167171.412591      0       NaN
# 2037       60.3992    110025.726793      0       NaN
# 2429      120.3334    215781.034381      0       NaN
# 10644        17.68     33053.917333      0       NaN
# 11885     741.5884   1356677.243758      0       NaN
# 12069      46.8767     86152.300306      0       NaN
# 12074       27.604       50741.6728      0       NaN
# 12239      34.2202     62941.719241      0       NaN
# 21149      62.2838    130997.994657      0       NaN
# 22233      47.2729     98625.557262      0       NaN
# 22368      74.7561    156117.033216      0       NaN
# 22438     219.2859    457277.554544      0       NaN
# 22569        10.85        22705.578      0       NaN
# 30836      61.8299    114478.052475      0       NaN
# 31500     112.7421    210650.145994      0       NaN
# 31966      48.3679       90116.9407      0       NaN
# 32073      20.7144     38747.834353      0       NaN
# 32461      44.5568     83435.336871      0       NaN
# 32544        8.496     15916.988596      0       NaN
# 40669      35.0965     66701.948537      0       NaN
# 41084       21.065     39964.936614      0       NaN
# 42296      14.5947       27773.7141      0       NaN
# 50877       65.684    128670.367595      0      fall
# 50878      66.9409    131096.594532      0      fall
# 50879     240.5109    471104.393823      0      fall
# 50880     246.8734    483161.813589      0      fall
# 50881    6018.0927  11661366.380981      0      fall
# 51242     202.6685    384794.629344      0      fall
# 51243     209.6083    397815.501912      0      fall
# 51244    2844.3808   5389971.266306      0      fall
# 51245     222.9554    422446.431044      0      fall
# 51246    8513.4278  15968587.384242      0      fall
# 51930     357.7646     685818.81164      0       NaN
# 62480      12.3077     22185.633345      0       NaN
# 71008      78.3052    141733.232659      0       NaN
# 71206       7.5267     13650.724188      0       NaN
# 72640      52.2116     94646.570901      0       NaN
# 81271       5.9231     10818.779074      0       NaN
# 81372       7.5795     13843.285633      0       NaN
# 91181      29.6286      56458.51957      0       NaN
# 91211       8.3814      15954.41397      0       NaN
# 92723     148.6858     283267.72159      0       NaN
# 92774       9.8545     18766.099754      0       NaN
# 101062   2610.0343   4746655.082251      0      fall
# 101063   3845.2243   6970297.757898      0      fall
# 101064   2351.3745   4258234.973878      0      fall
# 102644     24.7102      43413.54468      0       NaN
# 102796     13.9305      24348.84234      0       NaN
# 111217     91.5087    157945.185219      0      rise
# 111218      80.826    139485.569506      0      rise
# 111219     121.172    209194.364228      0      rise
# 111220    416.1299    719044.213918      0      rise
# 111221  10622.5966  18611402.304507      0      rise
# 112175     37.2167     64303.671251      0       NaN
# 112356     52.7465     91042.825016      0       NaN
# 112469      2.7448      4736.546548      0       NaN
# 112779      2.4138      4178.256974      0       NaN
# Number of rows with empty "tweets": 57

# %%
# Negate the mask to get a mask for rows where 'tweets' is not empty
non_empty_tweets_mask = combined_df['tweets'] != ''

# Filter combined_df using the mask
combined_df = combined_df[non_empty_tweets_mask]

# Check the dataframe
print(combined_df)
# Out:
#                         OpenTime OpenPrice HighPrice LowPrice ClosePrice  \
# 733    2023-04-01 12:13:00+00:00   1824.71   1824.87  1824.71    1824.79
# 1101   2023-04-01 18:21:00+00:00   1814.32   1814.43  1813.78    1814.43
# 3078   2023-04-03 03:18:00+00:00   1774.72   1775.07  1774.52    1775.07
# 3407   2023-04-03 08:47:00+00:00   1809.99   1811.11  1807.29    1809.38
# 3677   2023-04-03 13:17:00+00:00   1803.59   1804.29  1803.59    1804.29
# ...                          ...       ...       ...      ...        ...
# 110525 2023-06-16 18:05:00+00:00   1700.84    1710.0  1700.73    1705.72
# 113085 2023-06-18 12:45:00+00:00   1735.71   1736.27  1734.83    1736.23
# 113710 2023-06-18 23:10:00+00:00   1723.84   1724.34  1723.22    1724.33
# 114400 2023-06-19 10:40:00+00:00   1725.08   1725.08  1724.69    1725.07
# 114474 2023-06-19 11:54:00+00:00   1725.95   1726.04  1725.74    1725.75
#
#            Volume               CloseTime     QuoteVolume TradesN   TakerVol  \
# 733      209.8126 2023-04-01 12:13:59.999   382864.474937     318   128.7462
# 1101     196.6477 2023-04-01 18:21:59.999   356714.735043     319    50.3513
# 3078     138.0514 2023-04-03 03:18:59.999   245012.566725     401    65.7213
# 3407     724.5519 2023-04-03 08:47:59.999  1310667.490075    1415   288.6194
# 3677       91.733 2023-04-03 13:17:59.999   165480.902913     465    59.3711
# ...           ...                     ...             ...     ...        ...
# 110525  2772.2844 2023-06-16 18:05:59.999  4729860.129752    3094  1606.1452
# 113085   276.8724 2023-06-18 12:45:59.999   480513.324716     539   155.5568
# 113710   197.2032 2023-06-18 23:10:59.999   339908.969495     196   158.8211
# 114400   218.5093 2023-06-19 10:40:59.999    376922.37625     287   117.4692
# 114474    69.7937 2023-06-19 11:54:59.999   120464.419495     143     9.9555
#
#              TakerQVol Ignore Direction  \
# 733      234932.007283      0       NaN
# 1101      91332.881275      0       NaN
# 3078     116641.305386      0       NaN
# 3407     522056.636511      0       NaN
# 3677     107105.680557      0       NaN
# ...                ...    ...       ...
# 110525  2740494.207503      0      rise
# 113085   269967.828142      0       NaN
# 113710   273751.750876      0       NaN
# 114400   202627.078361      0       NaN
# 114474    17182.786842      0       NaN
#
#                                                    tweets
# 733     ECB'S DE GUINDOS: THE EUROZONE BANKING SECTOR ...
# 1101    ECB'S DE GUINDOS: THE EUROZONE BANKING SECTOR ...
# 3078    NORWAY’S KRONE LEADS COMMODITY FX HIGHER AFTER...
# 3407    PBOC ESTABLISHES YUAN MID-POINT AT 6.8805 /DLR...
# 3677    JAPAN'S PM KISHIDA: JAPAN'S FINANCIAL SYSTEM I...
# ...                                                   ...
# 110525  ECB: €29.4 BLN OF TLTRO FUNDS TO BE REPAID EAR...
# 113085  UK'S CHANCELLOR HUNT RULES OUT DIRECT SUPPORT ...
# 113710  SENIOR US STATE DEPT. OFFICIALS: US SECRETARY ...
# 114400  CHINA'S TOP ENVOY WANG YI IN MEETING WITH BLIN...
# 114474  CHINA'S TOP ENVOY WANG YI IN MEETING WITH BLIN...
#
# [315 rows x 14 columns]

# %% [markdown]
# #5 Dataset to OpenAI rules formatting

# %%
# Define the function to create 'completion' column based on 'Direction'
def generate_completion(direction):
    if direction == 'rise':
        return "Go long! I expect the eth price to rise!"
    elif direction == 'fall':
        return "Go short! I feel the eth price's gonna fall hard!"
    else:
        return "I don't see anything unusual, no prediction, sir."

# %%
# Replace NaN values in 'Direction' with 'no_change'
combined_df['Direction'].fillna('no_change', inplace=True)

# Create the 'prompt' column
combined_df['prompt'] = "Current time is " + combined_df['OpenTime'].dt.strftime('%Y-%m-%d %H:%M:%S') + "\nFinancial tweets for the last 8 hours: \n" + combined_df['tweets'] + "\nWhat is your prediction on ETH price movement? ->"

# Create the 'completion' column
combined_df['completion'] = "\n\n " + combined_df['Direction'].apply(generate_completion) + " ###"

# Create the new dataframe 'dataset' with only 'prompt' and 'completion' columns
dataset = combined_df[['prompt', 'completion', 'Direction']]

# Check the dataframe
print(dataset)
# Out:
#                                                    prompt  \
# 733     Current time is 2023-04-01 12:13:00\nFinancial...
# 1101    Current time is 2023-04-01 18:21:00\nFinancial...
# 3078    Current time is 2023-04-03 03:18:00\nFinancial...
# 3407    Current time is 2023-04-03 08:47:00\nFinancial...
# 3677    Current time is 2023-04-03 13:17:00\nFinancial...
# ...                                                   ...
# 110525  Current time is 2023-06-16 18:05:00\nFinancial...
# 113085  Current time is 2023-06-18 12:45:00\nFinancial...
# 113710  Current time is 2023-06-18 23:10:00\nFinancial...
# 114400  Current time is 2023-06-19 10:40:00\nFinancial...
# 114474  Current time is 2023-06-19 11:54:00\nFinancial...
#
#                                                completion  Direction
# 733     \n\n I don't see anything unusual, no predicti...  no_change
# 1101    \n\n I don't see anything unusual, no predicti...  no_change
# 3078    \n\n I don't see anything unusual, no predicti...  no_change
# 3407    \n\n I don't see anything unusual, no predicti...  no_change
# 3677    \n\n I don't see anything unusual, no predicti...  no_change
# ...                                                   ...        ...
# 110525  \n\n Go long! I expect the eth price to rise! ###       rise
# 113085  \n\n I don't see anything unusual, no predicti...  no_change
# 113710  \n\n I don't see anything unusual, no predicti...  no_change
# 114400  \n\n I don't see anything unusual, no predicti...  no_change
# 114474  \n\n I don't see anything unusual, no predicti...  no_change
#
# [315 rows x 3 columns]

# %%
# let's check any row here
print(dataset.iloc[145]["completion"])
# Out:
#  I don't see anything unusual, no prediction, sir. ###

# %%
#from sklearn.model_selection import train_test_split

# Split the data into training and test sets, with stratification over the 'Direction' column
#train_df, test_df = train_test_split(dataset, test_size=0.2, random_state=42, stratify=dataset['Direction'])

# Check the lengths of the training and test sets
#len(train_df), len(test_df)
#train_df[['prompt', 'completion']].to_json(path+"training2.jsonl", orient='records', lines=True)

# %%
#migrating from Goole colab to local machine, so I will upload my dataframes here
#import pandas as pd

#test_df = pd.read_csv('./test_df.csv')
#train_df = pd.read_csv('./train_df.csv')

# %%
import openai

# OpenAI completion function with prompt, model, max_tokens, temperature, and top_p as inputs
def completion(prompt, model):
  openai.api_key = os.getenv("OPENAI_API_KEY")
  output = openai.Completion.create(
        model=model,
        prompt= str(prompt)
    )
  return output.choices[0]['text'].strip(" \n")

# %%
# %env OPENAI_API_KEY=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
# Out:
# env: OPENAI_API_KEY=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

# %%
print(os.getenv("OPENAI_API_KEY"))
# Out:
# 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

# %%
# service block to count tokens, you can skip it

def count_words(text):
    words = text.split()  # This splits the text into words at spaces
    return len(words)

# Apply function to every row in 'prompt'
test_df['word_count'] = test_df['prompt'].apply(count_words)

# Filter DataFrame where 'Direction' equals 'rise'
filtered_df = test_df[test_df['Direction'] == 'fall']

print(filtered_df[['Direction', 'word_count']])
# Out:
#    Direction  word_count
# 1       fall         656
# 10      fall        1207
# 12      fall         904
# 15      fall        2119
# 19      fall        1405
# 23      fall         656
# 24      fall        1794
# 26      fall         791
# 27      fall         357
# 29      fall        1418
# 32      fall        1182
# 33      fall         357
# 35      fall        1080
# 36      fall        1824
# 53      fall        1081
# 55      fall        1220
# 57      fall         904
# 60      fall         791
# 63      fall          39

# %%
print(test_df.iloc[1]["prompt"])
# Out:
# Current time is 2023-04-21 19:04:00
# Financial tweets for the last 8 hours:
# GAZPROM: RUSSIAN GAS PRICE REPORTS FOR KAZAKHSTAN ARE INACCURATE.
# MORNING JUICE - US SESSION PREP financialjuice.com/News/7354…
# FITCH RATINGS: QT DECREASING US BANKS LIQUIDITY MAY WORSEN THE CREDIT SQUEEZE.
# QT REDUCING US BANKING LIQUIDITY, COULD AMPLIFY CREDIT SQUEEZE - FITCH RATINGS fitchratings.com/research/so…
# COINBASE CONSIDERS US FUTURE AS CRACKDOWN ROLLS ON - FT. ft.com/content/4ab352b5-5152…
# CANADIAN RETAIL SALES MOM ACTUAL -0.2% (FORECAST -0.6%, PREVIOUS 1.4%) $MACRO
# CANADIAN CORE RETAIL SALES MOM ACTUAL -0.7% (FORECAST 0%, PREVIOUS 0.9%) $MACRO
# CANADIAN RETAIL SALES FEBRUARY 2023 FULL REPORT www150.statcan.gc.ca/n1/dail…
# FANNIE MAE'S ESR GROUP: SEE ADDITIONAL, INCREMENTAL TIGHTENING IN CREDIT CONDITIONS TO CONTRIBUTE TO A MODEST RECESSION BEGINNING IN THE H2 OF 2023.
# FANNIE MAE'S ESR GROUP: EXPECTS ONLY ONE ADDITIONAL 25 BASIS POINT HIKE FROM THE FED IN MAY.
# FANNIE MAE'S ESR GROUP: DUE TO THE CONTINUALLY LOW INVENTORY OF AVAILABLE HOMES FOR SALE, EXPECT SALES ACTIVITY IN THE HOUSING INDUSTRY TO REMAIN SUBDUED.
# EFFECTIVE FED FUNDS RATE 4.83% APRIL 20 VS 4.83% APRIL 19.
# US S&P MANUFACTURING PMI FLASH ACTUAL 50.4 (FORECAST 49, PREVIOUS 49.2) $MACRO
# US S&P SERVICES PMI FLASH ACTUAL 53.7 (FORECAST 51.5, PREVIOUS 52.6) $MACRO
# US S&P COMPOSITE PMI FLASH  ACTUAL 53.5 (FORECAST 51.2, PREVIOUS 52.3) $MACRO
# US S&P PMI PRELIM APRIL 2023 FULL REPORT. pmi.spglobal.com/Public/Home…
# CHINA'S VICE FOREIGN MINISTER MET WITH WEST AUSTRALIA PREMIER - CHINESE FOREIGN MINISTRY.
# ITALIAN DELEGATION DISCUSSED THE CHIP DEALS IN TAIWAN - MINISTER.
# CRYPTO FEAR AND GREED INDEX: 50/100 = NEUTRAL
# WELLS FARGO DOWNGRADES US LARGE CAP EQUITIES FROM MOST FAVORABLE TO FAVORABLE.
# WATCH LIVE - ECB'S ELDERSON SPEAKS  invidious.fdn.fr/0x2JJMSgLws
# WELLS FARGO UPGRADES EUROPEAN EQUITIES TO NEUTRAL FROM UNFAVORABLE.
# SPAIN IS HIT WITH A TECHNICAL DEFAULT CLAIM IN A RENEWABLES DISPUTE.
# RUSSIAN FOREIGN MINISTRY: THE EXPIRY OF THE NEW START NUCLEAR TREATY COULD LEAD TO A VACUUM IN STRATEGIC STABILITY, WE NEED TO BE PREPARED FOR ALL SCENARIOS - RIA.
# US TREASURY SECRETARY YELLEN: THE FSOC TOOL IS AN IMPORTANT METHOD FOR REDUCING SYSTEMIC RISK.
# US TREASURY SECRETARY YELLEN: NONBANK DESIGNATION WAS MADE MORE DIFFICULT BY 2019 GUIDANCE.
# US TREASURY SECRETARY YELLEN SPEAKS - WATCH LIVE invidious.fdn.fr/bE8Y0nxQJHo
# US TREASURY SECRETARY YELLEN: THE NON-BANK DESIGNATION PROCESS WILL BE "RIGOROUS AND TRANSPARENT," ALLOWING FOR EXTENSIVE ENGAGEMENT WITH FIRMS UNDER REVIEW.
# US TREASURY SECRETARY YELLEN: FSOC RISK ANALYSIS FRAMEWORK FOR ASSESSING COMMON VULNERABILITIES AND FINANCIAL SHOCK TRANSMISSION CHANNELS
# US TREASURY SECRETARY YELLEN: THE FSOC WILL VOTE ON A PROPOSED NEW FRAMEWORK FOR IDENTIFYING, ASSESSING, AND RESPONDING TO FINANCIAL STABILITY RISKS.
# US TREASURY SECRETARY YELLEN: THE FINANCIAL SERVICES OVERSIGHT COUNCIL WILL VOTE ON REVISIONS TO THE GUIDANCE FOR DESIGNATING NON-BANK FINANCIAL INSTITUTIONS AS SYSTEMATICALLY IMPORTANT.
# US TREASURY SECRETARY YELLEN: THE UNITED STATES REMAINS VIGILANT AND CLOSELY MONITORS FINANCIAL SYSTEM CONDITIONS.
# US TREASURY SECRETARY YELLEN: THE MARCH BANKING TURMOIL DEMONSTRATES THAT MORE WORK IS NEEDED TO STRENGTHEN THE REGULATORY AND SUPERVISORY REGIMES.
# US TREASURY SECRETARY YELLEN: THE BANKING SYSTEM IN THE UNITED STATES HAS STABILIZED IN RECENT WEEKS AND REMAINS SOUND.
# FED'S POWELL: PROPOSED FSOC CHANGES TO CREATE A RISK-BALANCED APPROACH.
# US TREASURY SECRETARY YELLEN: FSOC IS PROPOSING TO ELIMINATE INAPPROPRIATE HURDLES TO DESIGNATING NON-BANK FIRMS FOR SUPERVISION ENACTED IN 2019.
# S&P GLOBAL MARKET INTELLIGENCE: FIVE-YEAR CREDIT DEFAULT SWAPS IN THE UNITED STATES HAVE RISEN TO 51 BASIS POINTS, THE HIGHEST LEVEL SINCE 2012.
# SOURCE CORRECTS TO 2011, NOT 2012
# US BAKER HUGHES OIL RIG COUNT ACTUAL 591 (FORECAST -, PREVIOUS 588) $MACRO
# US BAKER HUGHES TOTAL RIG COUNT ACTUAL 753 (FORECAST -, PREVIOUS 748) $MACRO
# 105 COUNTERPARTIES TAKE $2.290 TLN AT THE FED REVERSE REPO OPERATION.
# BOE’S RAMSDEN SEES RISK OF MORE PERSISTENT INFLATION - THE TIMES
# NYMEX GASOLINE MAY FUTURES SETTLE AT $2.6016 A GALLON.
# NYMEX WTI CRUDE JUNE FUTURES SETTLE AT $77.87 A BARREL, ,UP 50 CENTS, 0.65%.
# NYMEX DIESEL MAY FUTURES SETTLE AT $2.4886 A GALLON.
# NYMEX NATURAL GAS MAY FUTURES SETTLE AT $2.2330/MMBTU.
# ICE BRENT CRUDE JUNE FUTURES SETTLE AT $81.66/BBL.
# What is your prediction on ETH price movement? ->

# %%
print(completion(test_df.iloc[63]["prompt"], "davinci:ft-myself:gmx-2023-06-22-12-52-07"))
# Out:
# I don't see anything unusual, no prediction, sir. ### I

# %% [markdown]
# ***
# Finally!
# Ok, works randomly)) but lots of fun, keep moving, let's build an autimated tool

# %%
import os
import pandas as pd
import subprocess
from datetime import datetime, timedelta
import openai

# OpenAI completion function with prompt, model, max_tokens, temperature, and top_p as inputs
def completion(prompt, model):
  openai.api_key = os.getenv("OPENAI_API_KEY")
  output = openai.Completion.create(
        model=model,
        prompt= str(prompt)
    )
  return output.choices[0]['text'].strip(" \n")

def generate_prompt(tweets_df):
    # Get current time
    current_time = datetime.now()

    # Format current time into string
    current_time_str = current_time.strftime('%Y-%m-%d %H:%M:%S')

    # Combine all tweets with ' // ' separator
    combined_tweets = "\n".join(tweets_df['text'].values)

    # Construct the prompt
    prompt = "Current time is " + current_time_str + "\nFinancial tweets for the last 8 hours: \n" + combined_tweets + "\nWhat is your prediction on ETH price movement? ->"

    return prompt

# %env OPENAI_API_KEY=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

# Calculate the start and end dates
end_date = datetime.now()
start_date = end_date - timedelta(hours=8)

# Format the dates
start_date_str = start_date.strftime('%Y-%m-%d_%H:%M:%S')
end_date_str = end_date.strftime('%Y-%m-%d_%H:%M:%S')

# Define the Go command
cmd = [
    'go', 'run', 'main.go',
    '-Query', f'(from:financialjuice) since:{start_date_str}_UTC until:{end_date_str}_UTC',
    '-Instance', 'nitter.lacontrevoie.fr',
    '-Format', 'csv'
]

# Run the Go command and save the output to a file
with open('/Users/Vladimir/Desktop/actual_tweets.csv', 'w') as f:
    subprocess.run(cmd, stdout=f, cwd='/Users/Vladimir/DEV/twint-zero')

# Names of the attributes for the dataframe
column_names = ["ID", "Link", "datetime", "Account", "AccountName", "text", "Media", "Engage1", "Engage2", "Engage3", "Engage4"] 

# Load the CSV file into a DataFrame
df = pd.read_csv('/Users/Vladimir/Desktop/actual_tweets.csv', names=column_names)[['text']]


print(completion(generate_prompt(df), "davinci:ft-myself:gmx-2023-06-22-12-52-07"))
# Out:
# env: OPENAI_API_KEY=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
# I don't see anything unusual, no prediction, sir. ### Go
